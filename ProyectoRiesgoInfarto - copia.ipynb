# %% [markdown]
# # PROYECTO: Utilización de Machine Learning para la predicción del Riesgo de infarto

# %% [markdown]
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <title>Tarjeta de Información de Gráfico</title>
#     <style>
#         body {
#             font-family: 'Arial', sans-serif;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             min-height: 100vh;
#             background-color: #f4f4f4;
#             margin: 0;
#         }
#
#         .graph-card {
#             background-color: white;
#             border-radius: 12px;
#             box-shadow: 0 10px 25px rgba(0, 0, 0, 0.1);
#             padding: 25px;
#             width: 350px;
#             max-width: 90%;
#             transition: transform 0.3s ease;
#         }
#
#         .graph-card:hover {
#             transform: scale(1.02);
#         }
#
#         .card-header {
#             display: flex;
#             align-items: center;
#             margin-bottom: 20px;
#         }
#
#         .card-icon {
#             background-color: #3498db;
#             color: white;
#             border-radius: 50%;
#             width: 50px;
#             height: 50px;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             margin-right: 15px;
#         }
#
#         .card-title {
#             font-size: 1.2em;
#             font-weight: bold;
#             color: #2c3e50;
#         }
#
#         .graph-details {
#             background-color: #f8f9fa;
#             border-radius: 8px;
#             padding: 15px;
#         }
#
#         .detail-row {
#             display: flex;
#             justify-content: space-between;
#             margin-bottom: 10px;
#             border-bottom: 1px solid #e9ecef;
#             padding-bottom: 10px;
#         }
#
#         .detail-row:last-child {
#             border-bottom: none;
#         }
#
#         .detail-label {
#             color: #7f8c8d;
#         }
#
#         .detail-value {
#             font-weight: bold;
#             color: #2c3e50;
#         }
#
#         .trend-indicator {
#             font-size: 0.9em;
#             margin-left: 10px;
#         }
#
#         .positive-trend {
#             color: #2ecc71;
#         }
#
#         .negative-trend {
#             color: #e74c3c;
#         }
#     </style>
# </head>
# <body>
#     <div class="graph-card">
#         <div class="card-header">
#             <div class="card-icon">📊</div>
#             <div class="card-title">Análisis de Gráfico</div>
#         </div>
#         <div class="graph-details">
#             <div class="detail-row">
#                 <span class="detail-label">Ventas Totales</span>
#                 <span class="detail-value">$456,789
#                     <span class="trend-indicator positive-trend">▲ 12.3%</span>
#                 </span>
#             </div>
#             <div class="detail-row">
#                 <span class="detail-label">Crecimiento Mensual</span>
#                 <span class="detail-value">5.6%
#                     <span class="trend-indicator positive-trend">▲</span>
#                 </span>
#             </div>
#             <div class="detail-row">
#                 <span class="detail-label">Unidades Vendidas</span>
#                 <span class="detail-value">3,450
#                     <span class="trend-indicator negative-trend">▼ 2.1%</span>
#                 </span>
#             </div>
#             <div class="detail-row">
#                 <span class="detail-label">Período</span>
#                 <span class="detail-value">Octubre 2024</span>
#             </div>
#         </div>
#     </div>
# </body>
# </html>

# %% [markdown]
# ## Contenido
# ##### Este conjunto de datos sintéticos proporciona una amplia gama de características relevantes para la salud cardíaca y las opciones de estilo de vida, que abarcan detalles específicos del paciente, como edad, sexo, niveles de colesterol, presión arterial, frecuencia cardíaca e indicadores como diabetes, antecedentes familiares, hábito de fumar, obesidad y consumo de alcohol. Además, se incluyen factores de estilo de vida como horas de ejercicio, hábitos alimentarios, niveles de estrés y horas de sedentarismo. Se consideran aspectos médicos que comprenden problemas cardíacos previos, uso de medicamentos y niveles de triglicéridos. Se incorporan aspectos socioeconómicos como ingresos y atributos geográficos como país, continente y hemisferio. El conjunto de datos, que consta de 8763 registros de pacientes de todo el mundo, culmina en una característica de clasificación binaria que denota la presencia o ausencia de un riesgo de ataque cardíaco, lo que proporciona un recurso integral para el análisis predictivo y la investigación en salud cardiovascular.

# %% [markdown]
# ## Acerca del dataset
# ### Descripción del conjunto de columnas del dataset
#
# + Identificación del paciente : identificador único para cada paciente
# + Edad - Edad del paciente
# + Sexo - Género del paciente (Masculino/Femenino)
# + Colesterol - El colesterol LDL, también conocido como colesterol "malo", se acumula en las paredes de las arterias y puede contribuir a la obstrucción de estas.
#
# <table>
#   <thead>
#     <tr>
#       <th>Nivel de Colesterol LDL (mg/dL)</th>
#       <th>Categoría</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Menos de 100</td>
#       <td>Óptimo</td>
#     </tr>
#     <tr>
#       <td>100-129</td>
#       <td>Casi óptimo o poco mejor que óptimo</td>
#     </tr>
#     <tr>
#       <td>130-159</td>
#       <td>Límite alto</td>
#     </tr>
#     <tr>
#       <td>160-189</td>
#       <td>Alto</td>
#     </tr>
#     <tr>
#       <td>190 o mayor</td>
#       <td>Muy alto</td>
#     </tr>
#   </tbody>
# </table>
#
# + Presión arterial : presión arterial del paciente (sistólica/diastólica). La presión arterial sistólica es la presión en las arterias cuando el corazón late, y la diastólica es la presión entre un latido y el siguiente.
#
# <table>
#   <thead>
#     <tr>
#       <th>Categoría</th>
#       <th>Presión Arterial Sistólica (mmHg)</th>
#       <th>Presión Arterial Diastólica (mmHg)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Normal</td>
#       <td>Menor a 120</td>
#       <td>Menor a 80</td>
#     </tr>
#     <tr>
#       <td>Elevada</td>
#       <td>120-129</td>
#       <td>Menor a 80</td>
#     </tr>
#     <tr>
#       <td>Hipertensión grado 1</td>
#       <td>130-139</td>
#       <td>80-89</td>
#     </tr>
#     <tr>
#       <td>Hipertensión grado 2</td>
#       <td>140 o mayor</td>
#       <td>90 o mayor</td>
#     </tr>
#     <tr>
#       <td>Crisis hipertensiva</td>
#       <td>Mayor a 180</td>
#       <td>Mayor a 120</td>
#     </tr>
#   </tbody>
# </table>
#
#
# + Frecuencia cardíaca - La frecuencia cardíaca es el número de veces que el corazón late en un minuto, también conocida como pulso. En reposo, una frecuencia cardíaca normal oscila entre 60 y 100 latidos por minuto.
# + Diabetes - Si el paciente tiene diabetes (Sí/No). La diabetes es una enfermedad crónica que se caracteriza por niveles elevados de azúcar en la sangre. Esto se debe a que el cuerpo no produce suficiente insulina, la hormona que regula el azúcar en la sangre, o no la usa de forma adecuada
# + Antecedentes familiares : antecedentes familiares de problemas relacionados con el corazón (1: Sí, 0: No)
# + Tabaquismo - Estado de tabaquismo del paciente (1: Fumador, 0: No fumador)
# + Obesidad - Estado de obesidad del paciente (1: Obeso, 0: No obeso)
# + Consumo de alcohol : nivel de consumo de alcohol por parte del paciente (Ninguno/Leve/Moderado/Alto)
# + Horas de ejercicio por semana - Número de horas de ejercicio por semana
# + Dieta - Hábitos alimentarios del paciente (Saludable/Regular/No saludable)
# + Problemas cardíacos previos : Problemas cardíacos previos del paciente (1: Sí, 0: No)
# + Uso de medicamentos - Uso de medicamentos por parte del paciente (1: Sí, 0: No)
# + Nivel de estrés : nivel de estrés informado por el paciente (1-10)
# + Horas de sedentarismo por día - Horas de actividad sedentaria por día
# + Ingresos - Nivel de ingresos del paciente
# + IMC - Índice de Masa Corporal (IMC) del paciente
# + Triglicéridos - Niveles de triglicéridos del paciente
#
# <table>
#   <thead>
#     <tr>
#       <th>Categoría</th>
#       <th>Niveles de Triglicéridos (mg/dl)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Saludables (adultos)</td>
#       <td>Menos de 150</td>
#     </tr>
#     <tr>
#       <td>Ligeramente altos</td>
#       <td>150-199</td>
#     </tr>
#     <tr>
#       <td>Altos</td>
#       <td>200-499</td>
#     </tr>
#     <tr>
#       <td>Muy altos</td>
#       <td>500 o más</td>
#     </tr>
#   </tbody>
# </table>
#
#
# + Días de actividad física por semana - Días de actividad física por semana
# + Horas de sueño por día - Horas de sueño por día
# + País - País del paciente
# + Continente - Continente donde reside el paciente
# + Hemisferio - Hemisferio donde reside el paciente
# + Riesgo de ataque cardíaco : presencia de riesgo de ataque cardíaco (1: Sí, 0: No)

# %% [markdown]
# # Importación de librerias y carga de dataset

# %%
# importaciones de kubrerias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Carga de archivo csv (dataset)
df = pd.read_csv("2heart_attack_prediction_dataset.csv")

# %% [markdown]
# # Visualización y eploración de los datos del dataset

# %%
# Visualización de las promeros 5 filas y últmos 5 filas del dataframe
df
# Out:
#      Patient ID   Age     Sex  Cholesterol Blood Pressure  Heart Rate  \
# 0       BMW7812  67.0    Male        208.0         158/88        72.0
# 1       CZE1114  21.0    Male        389.0         165/93        98.0
# 2       BNI9906  21.0  Female        324.0         174/99        72.0
# 3       JLN3497  84.0    Male        383.0        163/100        73.0
# 4       GFO8847  66.0    Male        318.0          91/88        93.0
# ...         ...   ...     ...          ...            ...         ...
# 8768    MSV9918  60.0    Male        121.0          94/76        61.0
# 8769    QSV6764  28.0  Female        120.0        157/102        73.0
# 8770    XKA5925  47.0    Male        250.0         161/75       105.0
# 8771    EPE6801  36.0    Male        178.0         119/67        60.0
# 8772    ZWN9666  25.0  Female        356.0         138/67        75.0
#
#       Diabetes  Family History  Smoking  Obesity  ...  \
# 0          0.0             0.0      1.0      0.0  ...
# ...

# %%
# Mostramos los principales datos estadísticos del dataset
df.describe()
# Out:
#                Age  Cholesterol   Heart Rate     Diabetes  Family History  \
# count  8772.000000  8772.000000  8772.000000  8772.000000     8772.000000
# mean     53.681601   259.893753    75.011400     0.652645        0.492476
# std      21.254547    80.823427    20.542907     0.476157        0.499972
# min      18.000000   120.000000    40.000000     0.000000        0.000000
# 25%      35.000000   192.000000    57.000000     0.000000        0.000000
# 50%      54.000000   259.000000    75.000000     1.000000        0.000000
# 75%      72.000000   330.000000    93.000000     1.000000        1.000000
# max      90.000000   400.000000   110.000000     1.000000        1.000000
#
#            Smoking      Obesity  Alcohol Consumption  Exercise Hours Per Week  \
# count  8772.000000  8772.000000          8772.000000              8772.000000
# mean      0.896945     0.501938             0.598495                10.017465
# ...

# %%
# Visualización de los datos estdisticos tranpuestos
df.describe().T
# Out:
#                                   count           mean           std  \
# Age                              8772.0      53.681601     21.254547
# Cholesterol                      8772.0     259.893753     80.823427
# Heart Rate                       8772.0      75.011400     20.542907
# Diabetes                         8772.0       0.652645      0.476157
# Family History                   8772.0       0.492476      0.499972
# Smoking                          8772.0       0.896945      0.304048
# Obesity                          8772.0       0.501938      0.500025
# Alcohol Consumption              8772.0       0.598495      0.490231
# Exercise Hours Per Week          8772.0      10.017465      5.781630
# Previous Heart Problems          8772.0       0.496352      0.500015
# Medication Use                   8772.0       0.498860      0.500027
# Stress Level                     8772.0       5.471272      2.858574
# Sedentary Hours Per Day          8772.0       5.988370      3.468555
# ...

# %% [markdown]
# ##### Lectura de los datos estadisticos de la columna Heart Rate (Frecuencia cardiaca) del dataset
# <FONT COLOR="#00FFFF">📊 El promedio de la frecuencia cardiaca es de 75.02, con una desviación estándard de 20.55 la cual mide la dispersión de los datos respecto a la media, siendo la frecuencia cardiaca minima de 40 bpm y una frecuencia máxima de 100. Respecto a los Cuartiles pordemos observar que el 25% de los pacientes tienen valores iguales o menos a 57 bpm y el 50 % de los valores estan por debajo de 75 bpm. este 50% representa a la mediana lo cual es interesante que coincida con la media, lo que sugiere una distribición aproximadamente simétrica y en el tercer cuartil tenemos los los valores iguales o menores al 93 bpm. De un total de 8763 pacientes.</FONT>

# %%
df.shape
# Out:
# (8773, 26)

# %%
df.describe(include=[object]).T
# Out:
#                count unique                  top  freq
# Patient ID      8772   8763              ATI9164    10
# Sex             8772      2                 Male  6120
# Blood Pressure  8772   3915                92/71    13
# Diet            8772      3              Healthy  2969
# Country         8772     20              Germany   477
# Continent       8772      6                 Asia  2552
# Hemisphere      8772      2  Northern Hemisphere  5669

# %%
# imprimimos un resumen del dataframe con informacion sobre valores no nulos, memora utilizada y tipo de datos 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8773 entries, 0 to 8772
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Patient ID                       8772 non-null   object
#  1   Age                              8772 non-null   float64
#  2   Sex                              8772 non-null   object
#  3   Cholesterol                      8772 non-null   float64
#  4   Blood Pressure                   8772 non-null   object
#  5   Heart Rate                       8772 non-null   float64
#  6   Diabetes                         8772 non-null   float64
#  7   Family History                   8772 non-null   float64
#  8   Smoking                          8772 non-null   float64
#  9   Obesity                          8772 non-null   float64
#  10  Alcohol Consumption              8772 non-null   float64
# ...

# %%
# Imprimimos los nombres de las columnas
df.columns
# Out:
# Index(['Patient ID', 'Age', 'Sex', 'Cholesterol', 'Blood Pressure',
#        'Heart Rate', 'Diabetes', 'Family History', 'Smoking', 'Obesity',
#        'Alcohol Consumption', 'Exercise Hours Per Week', 'Diet',
#        'Previous Heart Problems', 'Medication Use', 'Stress Level',
#        'Sedentary Hours Per Day', 'Income', 'BMI', 'Triglycerides',
#        'Physical Activity Days Per Week', 'Sleep Hours Per Day', 'Country',
#        'Continent', 'Hemisphere', 'Heart Attack Risk'],
#       dtype='object')

# %%
# Renombramos las columnas al español
df.columns = ['Identificación del paciente', 'Edad', 'Sexo', 'Colesterol', 'Tensión arterial',
       'Frecuencia cardiaca', 'Diabetes', 'Antecedentes familiares', 'Tabaquismo', 'Obesidad',
       'Consumo de alcohol', 'Horas ejercicio semanal', 'Dieta',
       'Problemas cardiacos previos', 'Uso de medicación', 'Nivel de estrés',
       'Horas de sedentarismo diarias', 'Ingresos', 'BMI', 'Triglicéridos',
       'Días de actividad física por semana', 'Horas de sueño por día', 'País',
       'Continente', 'Hemisferio', 'Riesgo de infarto']
df.columns
# Out:
# Index(['Identificación del paciente', 'Edad', 'Sexo', 'Colesterol',
#        'Tensión arterial', 'Frecuencia cardiaca', 'Diabetes',
#        'Antecedentes familiares', 'Tabaquismo', 'Obesidad',
#        'Consumo de alcohol', 'Horas ejercicio semanal', 'Dieta',
#        'Problemas cardiacos previos', 'Uso de medicación', 'Nivel de estrés',
#        'Horas de sedentarismo diarias', 'Ingresos', 'BMI', 'Triglicéridos',
#        'Días de actividad física por semana', 'Horas de sueño por día', 'País',
#        'Continente', 'Hemisferio', 'Riesgo de infarto'],
#       dtype='object')

# %%
# Buscamos y sumamos los valores nulos en caso de existir
df.isnull().sum()
# Out:
# Identificación del paciente            1
# Edad                                   1
# Sexo                                   1
# Colesterol                             1
# Tensión arterial                       1
# Frecuencia cardiaca                    1
# Diabetes                               1
# Antecedentes familiares                1
# Tabaquismo                             1
# Obesidad                               1
# Consumo de alcohol                     1
# Horas ejercicio semanal                1
# Dieta                                  1
# Problemas cardiacos previos            1
# Uso de medicación                      1
# Nivel de estrés                        1
# Horas de sedentarismo diarias          1
# Ingresos                               1
# BMI                                    1
# Triglicéridos                          1
# Días de actividad física por semana    1
# Horas de sueño por día                 1
# País                                   1
# ...

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Identificación del paciente            0
# Edad                                   0
# Sexo                                   0
# Colesterol                             0
# Tensión arterial                       0
# Frecuencia cardiaca                    0
# Diabetes                               0
# Antecedentes familiares                0
# Tabaquismo                             0
# Obesidad                               0
# Consumo de alcohol                     0
# Horas ejercicio semanal                0
# Dieta                                  0
# Problemas cardiacos previos            0
# Uso de medicación                      0
# Nivel de estrés                        0
# Horas de sedentarismo diarias          0
# Ingresos                               0
# BMI                                    0
# Triglicéridos                          0
# Días de actividad física por semana    0
# Horas de sueño por día                 0
# País                                   0
# ...

# %% [markdown]
# ##### Luego de observar los resultados se da por validado que no existen valores nulos  y que el dataset esta limpio para proceder con el análisis

# %% [markdown]
# # Graficos

# %%
df.duplicated().sum()
# Out:
# np.int64(9)

# %%
df.drop_duplicates()
# Out:
#      Identificación del paciente  Edad    Sexo  Colesterol Tensión arterial  \
# 0                        BMW7812  67.0    Male       208.0           158/88
# 1                        CZE1114  21.0    Male       389.0           165/93
# 2                        BNI9906  21.0  Female       324.0           174/99
# 3                        JLN3497  84.0    Male       383.0          163/100
# 4                        GFO8847  66.0    Male       318.0            91/88
# ...                          ...   ...     ...         ...              ...
# 8768                     MSV9918  60.0    Male       121.0            94/76
# 8769                     QSV6764  28.0  Female       120.0          157/102
# 8770                     XKA5925  47.0    Male       250.0           161/75
# 8771                     EPE6801  36.0    Male       178.0           119/67
# 8772                     ZWN9666  25.0  Female       356.0           138/67
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(9)

# %%
colores = ["#adc15e","#97a952","#829147","#6c793b","#56612f","#414823","#2b3018","#16180c"]

df2 = df[["Continente","Riesgo de infarto","Frecuencia cardiaca","Dieta"]] # Guardamos los datos en un nuevo dataframe
df2.head() # mostramos el resultado del nuevo dataframe
# Out:
#       Continente  Riesgo de infarto  Frecuencia cardiaca      Dieta
# 0  South America                0.0                 72.0    Average
# 1  North America                0.0                 98.0  Unhealthy
# 2         Europe                0.0                 72.0    Healthy
# 3  North America                0.0                 73.0    Average
# 4           Asia                0.0                 93.0  Unhealthy

# %%
df2
# Out:
#          Continente  Riesgo de infarto  Frecuencia cardiaca      Dieta
# 0     South America                0.0                 72.0    Average
# 1     North America                0.0                 98.0  Unhealthy
# 2            Europe                0.0                 72.0    Healthy
# 3     North America                0.0                 73.0    Average
# 4              Asia                0.0                 93.0  Unhealthy
# ...             ...                ...                  ...        ...
# 8768           Asia                0.0                 61.0    Healthy
# 8769  North America                0.0                 73.0    Healthy
# 8770  South America                1.0                105.0    Average
# 8771  South America                0.0                 60.0  Unhealthy
# 8772         Europe                1.0                 75.0    Healthy
#
# [8772 rows x 4 columns]

# %%
df2 = df2.groupby(by="Continente").count()
df2 = df2.reset_index()
df2
# Out:
#       Continente  Riesgo de infarto  Frecuencia cardiaca  Dieta
# 0         Africa                873                  873    873
# 1           Asia               2552                 2552   2552
# 2      Australia                884                  884    884
# 3         Europe               2241                 2241   2241
# 4  North America                860                  860    860
# 5  South America               1362                 1362   1362

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8772 entries, 0 to 8772
# Data columns (total 26 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Identificación del paciente          8772 non-null   object
#  1   Edad                                 8772 non-null   float64
#  2   Sexo                                 8772 non-null   object
#  3   Colesterol                           8772 non-null   float64
#  4   Tensión arterial                     8772 non-null   object
#  5   Frecuencia cardiaca                  8772 non-null   float64
#  6   Diabetes                             8772 non-null   float64
#  7   Antecedentes familiares              8772 non-null   float64
#  8   Tabaquismo                           8772 non-null   float64
#  9   Obesidad                             8772 non-null   float64
#  10  Consumo de alcohol                   8772 non-null   float64
# ...

# %%
correlacion = df.select_dtypes(include=["number"])
correlacion2 = df.select_dtypes(include=["object"])
correlacion = correlacion.corr()
correlacion2
# Out:
#      Identificación del paciente    Sexo Tensión arterial      Dieta  \
# 0                        BMW7812    Male           158/88    Average
# 1                        CZE1114    Male           165/93  Unhealthy
# 2                        BNI9906  Female           174/99    Healthy
# 3                        JLN3497    Male          163/100    Average
# 4                        GFO8847    Male            91/88  Unhealthy
# ...                          ...     ...              ...        ...
# 8768                     MSV9918    Male            94/76    Healthy
# 8769                     QSV6764  Female          157/102    Healthy
# 8770                     XKA5925    Male           161/75    Average
# 8771                     EPE6801    Male           119/67  Unhealthy
# 8772                     ZWN9666  Female           138/67    Healthy
#
#                 País     Continente           Hemisferio
# 0          Argentina  South America  Southern Hemisphere
# ...

# %%
duplicados = df.duplicated().sum()
duplicados
# Out:
# np.int64(9)

# %%
plt.hist(df["Edad"], bins=15, color='lightgreen', edgecolor='black')
plt.title('Distribución de Edades')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# %%
'''
x = df2["Continente"].tolist()
y = df2["Días de actividad física por semana"].tolist()

plt.pie(x, color=colores)
plt.xlabel("Continente")
plt.ylabel("Consumo de alcohol")
plt.title("Consumo de alcohol por continente")
plt.xticks(rotation=30)
plt.show()
'''
# Out:
# '\nx = df2["Continente"].tolist()\ny = df2["Días de actividad física por semana"].tolist()\n\nplt.pie(x, color=colores)\nplt.xlabel("Continente")\nplt.ylabel("Consumo de alcohol")\nplt.title("Consumo de alcohol por continente")\nplt.xticks(rotation=30)\nplt.show()\n'

# %%
# 
plt.pie(y, labels=x,autopct="%1.1f%%", colors=colores)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 2
#       1 #
# ----> 2 plt.pie(y, labels=x,autopct="%1.1f%%", colors=colores)
#       3 plt.show()
#
# NameError: name 'y' is not defined

# %%
plt.barh(x, y, color=colores)
plt.xlabel("Continente")
plt.ylabel("Consumo de alcohol")
plt.title("Consumo de alcohol por continente")
plt.show()

# %% [markdown]
# ### Grafico de Dispersión

# %%
df2
# Out:
#       Continente  Consumo de alcohol  Días de actividad física por semana  \
# 0         Africa            0.595647                             3.415808
# 1           Asia            0.602665                             3.496082
# 2      Australia            0.572398                             3.501131
# 3         Europe            0.597501                             3.547523
# 4  North America            0.615116                             3.493023
# 5  South America            0.600587                             3.403818
#
#    Horas de sueño por día  Horas de sedentarismo diarias  Riesgo de infarto  \
# 0                7.065292                       6.225261           0.368843
# 1                7.023511                       5.984514           0.352665
# 2                7.145928                       6.306213           0.360860
# 3                6.964748                       5.867825           0.345828
# ...

# %%
# para comparar la relacion de dos variables
x = df2["Riesgo de infarto"]
y = df2["Frecuencia cardiaca"]
plt.scatter(x ,y )
plt.show()

# %% [markdown]
# ### Histograma
# permite ver una relacion entre los datos y una frecuencia

# %%
df2
# Out:
#       Continente  Consumo de alcohol  Días de actividad física por semana  \
# 0         Africa            0.595647                             3.415808
# 1           Asia            0.602665                             3.496082
# 2      Australia            0.572398                             3.501131
# 3         Europe            0.597501                             3.547523
# 4  North America            0.615116                             3.493023
# 5  South America            0.600587                             3.403818
#
#    Horas de sueño por día  Horas de sedentarismo diarias  Riesgo de infarto  \
# 0                7.065292                       6.225261           0.368843
# 1                7.023511                       5.984514           0.352665
# 2                7.145928                       6.306213           0.360860
# 3                6.964748                       5.867825           0.345828
# ...

# %%
a = df2["Horas de sedentarismo diarias"].tolist()
b = df2["Días de actividad física por semana"].tolist()

plt.hist(a)
plt.show()

# %% [markdown]
# ## Grafico de lineas

# %%
df2.plot(x="Continente", y="Consumo de alcohol", kind="line")
# Out:
# <Axes: xlabel='Continente'>

# %% [markdown]
# ## Seaborn

# %% [markdown]
# ## grafico de tortas

# %%
df2.groupby(["Continente"]).sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Continente'>

# %%
sns.scatterplot(x="Horas de sedentarismo diarias", y="Días de actividad física por semana" ,data=df)
# Out:
# <Axes: xlabel='Horas de sedentarismo diarias', ylabel='Días de actividad física por semana'>

# %%
df.columns
# Out:
# Index(['Identificación del paciente', 'Edad', 'Sexo', 'Colesterol',
#        'Tensión arterial', 'Frecuencia cardiaca', 'Diabetes',
#        'Antecedentes familiares', 'Tabaquismo', 'Obesidad',
#        'Consumo de alcohol', 'Horas ejercicio semanal', 'Dieta',
#        'Problemas cardiacos previos', 'Uso de medicación', 'Nivel de estrés',
#        'Horas de sedentarismo diarias', 'Ingresos', 'BMI', 'Triglicéridos',
#        'Días de actividad física por semana', 'Horas de sueño por día', 'País',
#        'Continente', 'Hemisferio', 'Riesgo de infarto'],
#       dtype='object')

# %%
plt.figure(figsize=(16,6)) # Tamaño de la figura
sns.histplot(df["Edad"], kde=True, bins=18) 
plt.title("Distribución de la Edad", fontsize=16)
plt.xlabel("Edad", fontsize=14)
plt.ylabel("Frecuencia", fontsize=14)
plt.show()

# %% [markdown]
# 🧐Lectura: En el histograma, se puede observar que hay una distribución de las edades bastante uniforme sin mucha variacion, aunque podemos encontrar tres picos, entre los [26-30] [42-46] y el mas alto y pronunciado entre los [86-90]

# %%
# Formula para calcular el año de cada Bins
edadMin = 18
edadMax = 90
bin = 18

anchoBin = (edadMax - edadMin)/bin
print(anchoBin)
# Out:
# 4.0

# %%
plt.figure(figsize=(7,7)) # Tamaño de la figura
sns.boxplot(x=df["Riesgo de infarto"], y=df["Colesterol"]) 
plt.title("Colesterol", fontsize=16)
plt.xlabel("Riesgo de infarto", fontsize=14)
plt.ylabel("Frecuencia", fontsize=14)
plt.show()

# %%
# plt.figure(figsize=(7,7)) # Tamaño de la figura
sns.countplot(x=df["Sexo"], hue=df["Dieta"]) 
plt.title("Colesterol", fontsize=16)
plt.xlabel("Riesgo de infarto", fontsize=14)
plt.ylabel("Frecuencia", fontsize=14)
plt.show()

# %%
df.columns
# Out:
# Index(['Identificación del paciente', 'Edad', 'Sexo', 'Colesterol',
#        'Tensión arterial', 'Frecuencia cardiaca', 'Diabetes',
#        'Antecedentes familiares', 'Tabaquismo', 'Obesidad',
#        'Consumo de alcohol', 'Horas ejercicio semanal', 'Dieta',
#        'Problemas cardiacos previos', 'Uso de medicación', 'Nivel de estrés',
#        'Horas de sedentarismo diarias', 'Ingresos', 'BMI', 'Triglicéridos',
#        'Días de actividad física por semana', 'Horas de sueño por día', 'País',
#        'Continente', 'Hemisferio', 'Riesgo de infarto'],
#       dtype='object')

# %%
plt.hist(df['Colesterol'], bins=30, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Distribución del Colesterol')
plt.xlabel('Colesterol')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.scatter(df['Edad'], df['Colesterol'], alpha=0.5, color='red')
plt.title('Colesterol vs Edad')
plt.xlabel('Edad')
plt.ylabel('Colesterol')
plt.show()

# %%
for risk, group in df.groupby('Riesgo de infarto'):
    plt.scatter(group['Edad'], group['Colesterol'], alpha=0.6, label=f'Riesgo: {risk}')
plt.title('Colesterol vs Edad por Nivel de Riesgo')
plt.xlabel('Edad')
plt.ylabel('Colesterol')
plt.legend()
plt.show()

# %%
plt.boxplot([df[df['Sexo'] == 'Male']['Colesterol'], 
             df[df['Sexo'] == 'Female']['Colesterol']], 
            labels=['Hombres', 'Mujeres'])
plt.title('Colesterol por Sexo')
plt.ylabel('Colesterol')
plt.show()
# Out:
# C:\Users\porsc\AppData\Local\Temp\ipykernel_16892\778757710.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df[df['Sexo'] == 'Male']['Colesterol'],

# %%
df['Dieta'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['gold', 'lightblue', 'lightgreen'])
plt.title('Distribución de Tipos de Dieta')
plt.ylabel('')  # Oculta la etiqueta
plt.show()
